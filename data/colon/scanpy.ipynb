# %%
import scanpy as sc

# %%
adata = sc.read('C:\\Users\\DaniLivne\\Downloads\\CNSbordercellatlas_Dec22_RAWCOUNTS.h5ad')

# %%
adata.uns
# Out:
# OverloadedDict, wrapping:
# 	OrderedDict()
# With overloaded keys:
# 	['neighbors'].

# %%
adata.var
# Out:
#                    mt  n_cells_by_counts-0  mean_counts-0  \
# Xkr4            False                    0       0.000000
# Gm1992          False                    0       0.000000
# Gm37381         False                    0       0.000000
# Rp1             False                    1       0.000123
# Sox17           False                   14       0.003569
# ...               ...                  ...            ...
# AC234645.1      False                    0       0.000000
# AC168977.2      False                   30       0.003815
# AC168977.1      False                   57       0.007999
# Vmn2r122        False                    0       0.000000
# CAAA01147332.1  False                  246       0.031381
#
#                 pct_dropout_by_counts-0  total_counts-0  n_cells_by_counts-1  \
# Xkr4                         100.000000             0.0                   54
# Gm1992                       100.000000             0.0                    0
# ...

# %%
adata.write('C:\\Users\DaniLivne\\Documents\\Github\\Pathweigh\\data\\colon\\')
